# %%
import pandas as pd
df=pd.read_csv("country_vaccinations.csv.zip")

# %%
df
# Out:
#            country  ...                                     source_website
# 0      Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 1      Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 2      Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 3      Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 4      Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# ...            ...  ...                                                ...
# 55819     Zimbabwe  ...  https://www.arcgis.com/home/webmap/viewer.html...
# 55820     Zimbabwe  ...  https://www.arcgis.com/home/webmap/viewer.html...
# 55821     Zimbabwe  ...  https://www.arcgis.com/home/webmap/viewer.html...
# 55822     Zimbabwe  ...  https://www.arcgis.com/home/webmap/viewer.html...
# 55823     Zimbabwe  ...  https://www.arcgis.com/home/webmap/viewer.html...
#
# [55824 rows x 15 columns]

# %%
df.head()
# Out:
#        country  ...                                     source_website
# 0  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 1  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 2  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 3  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 4  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
#
# [5 rows x 15 columns]

# %%
import numpy as np
#missing values
features_with_na=[features for features in df.columns if df[features].isnull().sum()>1]
## 2- step print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, np.round(df[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# total_vaccinations 0.4601  % missing values
# people_vaccinated 0.4871  % missing values
# people_fully_vaccinated 0.5381  % missing values
# daily_vaccinations_raw 0.5575  % missing values
# daily_vaccinations 0.0045  % missing values
# total_vaccinations_per_hundred 0.4601  % missing values
# people_vaccinated_per_hundred 0.4871  % missing values
# people_fully_vaccinated_per_hundred 0.5381  % missing values
# daily_vaccinations_per_million 0.0045  % missing values

# %% [markdown]
# # New Section

# %%
#numerical variables
numerical_features = [feature for feature in df.columns if df[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
df[numerical_features].head()
# Out:
# Number of numerical variables:  9
#    total_vaccinations  ...  daily_vaccinations_per_million
# 0                 0.0  ...                             NaN
# 1                 NaN  ...                            34.0
# 2                 NaN  ...                            34.0
# 3                 NaN  ...                            34.0
# 4                 NaN  ...                            34.0
#
# [5 rows x 9 columns]

# %%
#temporal data variables
df.groupby('total_vaccinations')['total_vaccinations_per_hundred'].median( ).plot( )
plt.xlabel('total_vaccinations')
plt.ylabel('people_fully_vaccinated')
plt.title("total vaccinations vs people fully vaccinated")
# Out:
# Text(0.5, 1.0, 'total vaccinations vs people fully vaccinated')

# %%
import matplotlib.pyplot as plt
# Data to plot
labels = 'TV', 'PFV', 'DV', 'PV' 
sizes = [1400,1000,6178,496]
colors = ['gold', 'yellow', 'green', 'lightcoral']
explode = (0, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature+['total_vaccinations']]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 8

# %%
for feature in continuous_feature:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
categorical_features=[feature for feature in dataset.columns if data[feature].dtypes=='O']
categorical_feature

# %%
categorical_features=[feature for feature in df.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['country', 'iso_code', 'date', 'vaccines', 'source_name', 'source_website']

# %%
df[categorical_features].head()
# Out:
#        country  ...                                     source_website
# 0  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 1  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 2  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 3  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
# 4  Afghanistan  ...  https://reliefweb.int/sites/reliefweb.int/file...
#
# [5 rows x 6 columns]

# %%
#digits recongintion
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_digits
digits=load_digits()

# %%
import pylab as pl
pl.gray()
pl.matshow(digits.images[4])
pl.show()
